# %% [markdown]
# ## O objetivo deste projeto é poder modificar as cores de uma foto.

# %%
import pandas as np
import matplotlib.pyplot as plt

# %%
img = plt.imread('GIRASSOL.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (450, 600, 3)

# %%
plt.imshow(img)
plt.xticks([], []) #retirar ticks
plt.yticks([], [])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.imshow(img[:, :, 0])

# %%
plt.imshow(img[:, :, 1])

# %%
plt.imshow(img[:, :, 2])

# %%
plt.imshow(img[:, :, 0], cmap='gray')

# %%
plt.imshow(img[:, :, 1], cmap='gray')

# %%
plt.imshow(img[:, :, 2], cmap='gray')

# %%
img_R = img.copy()
img_R[:, :, [1, 2]] = 0
plt.imshow(img_R)
plt.xticks([], [])
plt.yticks([], [])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
img_G = img.copy()
img_G[:, :, [0, 2]] = 0
plt.imshow(img_G)
plt.xticks([], [])
plt.yticks([], [])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
img_B = img.copy()
img_B[:, :, [0, 1]] = 0
plt.imshow(img_B)
plt.xticks([], [])
plt.yticks([], [])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
